# %% [markdown]
# # 第 21 章 OpenCV 人臉辨識 — 預訓練模型下載

# %% [markdown]
# ### 21-3-1 SFace 模型準備

# %%
import os
import requests
from tqdm import tqdm

# 建立資料夾
os.makedirs("models", exist_ok=True)

# 模型檔案清單與對應的下載網址
models = {
    "face_recognition_sface_2021dec.onnx": "https://github.com/opencv/opencv_zoo/raw/main/models/face_recognition_sface/face_recognition_sface_2021dec.onnx"
}

# 迴圈檢查並下載檔案
for filename, url in models.items():
    filepath = os.path.join("models", filename)
    
    if os.path.exists(filepath):
        print(f"檔案已存在，跳過下載：{filename}")
        continue

    print(f"正在下載：{filename}")
    response = requests.get(url, stream=True)
    total_size = int(response.headers.get('content-length', 0))
    
    # 結合 tqdm 顯示下載進度條，並自動管理資源關閉
    with open(filepath, 'wb') as f, tqdm(total=total_size, unit='iB', unit_scale=True) as bar:
        for data in response.iter_content(1024):
            f.write(data)
            bar.update(len(data))
# Out:
# 正在下載：face_recognition_sface_2021dec.onnx
# 100%|██████████| 38.7M/38.7M [00:05<00:00, 7.53MiB/s]
